# %% [markdown]
# ## Install prerequisities

# %% [markdown]
# The only prerequisity needed at this time is installing Python Sparc Client library (sparc.client).
#
# Optionally, for uploading the files, Pennsieve Agent needs to be installed.
#
# For details, please follow the instruction on https://docs.pennsieve.io/docs/uploading-files-programmatically .

# %%
# !pip install sparc.client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sparc.client in /home/patrick/.local/lib/python3.10/site-packages (0.0.1)
# Requirement already satisfied: pennsieve2 in /home/patrick/.local/lib/python3.10/site-packages (from sparc.client) (0.1.1)
# Requirement already satisfied: requests>=2.28.0 in /home/patrick/.local/lib/python3.10/site-packages (from pennsieve2->sparc.client) (2.28.1)
# Requirement already satisfied: grpcio>=1.50 in /home/patrick/.local/lib/python3.10/site-packages (from pennsieve2->sparc.client) (1.51.1)
# Requirement already satisfied: grpcio_tools>=1.50 in /home/patrick/.local/lib/python3.10/site-packages (from pennsieve2->sparc.client) (1.50.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from pennsieve2->sparc.client) (4.21.9)
# Requirement already satisfied: sphinxcontrib-napoleon==0.7 in /home/patrick/.local/lib/python3.10/site-packages (from pennsieve2->sparc.client) (0.7)
# Requirement already satisfied: tqdm>=4.64 in /home/patrick/.local/lib/python3.10/site-packages (from pennsieve2->sparc.client) (4.64.1)
# Requirement already satisfied: six>=1.5.2 in /usr/lib/python3/dist-packages (from sphinxcontrib-napoleon==0.7->pennsieve2->sparc.client) (1.16.0)
# Requirement already satisfied: pockets>=0.3 in /home/patrick/.local/lib/python3.10/site-packages (from sphinxcontrib-napoleon==0.7->pennsieve2->sparc.client) (0.9.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from grpcio_tools>=1.50->pennsieve2->sparc.client) (59.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.28.0->pennsieve2->sparc.client) (2020.6.20)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/patrick/.local/lib/python3.10/site-packages (from requests>=2.28.0->pennsieve2->sparc.client) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28.0->pennsieve2->sparc.client) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.28.0->pennsieve2->sparc.client) (1.26.5)

# %% [markdown]
# ## Load modules

# %% [markdown]
# sparc.client has a modular structure. Modules can be loaded either automatically (without the 'connect' flag), or manually.
#
# In the following example we are loading a Pennsieve2 module and connecting to the Pennsieve agent runnin

# %%
from sparc.client import SparcClient
client = SparcClient(connect=False, config_file='../config/config.ini')

#Connect to a specific module - REQUIRES PENNSIEVE AGENT RUNNING
#module = client.pennsieve.connect()
#module.user.whoami() #execute internal functions of the module

# alternatively connect all the services available
#client.connect()  #connect to all services

# %% [markdown]
# Modules can also be loaded from other locations by simply providing a dictionary with configurations and path to the module.

# %%
#modules could also be added later by passing a config with env variables and path to the module  
client.add_module(config={'pennsieve_profile_name' : 'ci'}, 
                  path = 'sparc.client.services.pennsieve', 
                  connect=False)

# %% [markdown]
# ## Pennsieve Module API

# %% [markdown]
# Pennsieve module allows users to interact with Pennsieve platform.
#
# Without connecting to the agent, the user is able to query Discover service of the Pennsieve platform for databases, specific files and records as well as to download publicly available files or datasets.

# %% [markdown]
# #### Listing datasets

# %% [markdown]
# Listing a dataset that match a specific word, e.g. the last name of the PI or a medical term could be performed the following way:

# %%
response=client.pennsieve.list_datasets(query='Wagenaar')
response
# Out:
# {'limit': 10,
#  'offset': 0,
#  'totalCount': 5,
#  'datasets': [{'id': 3,
#    'sourceDatasetId': 13,
#    'name': 'Canine Epilepsy Dataset',
#    'description': 'Intracranial EEG recordings from three dogs with naturally-occurring focal epilepsy.',
#    'ownerId': 97,
#    'ownerFirstName': 'Jacqueline',
#    'ownerLastName': 'Boccanfuso',
#    'ownerOrcid': '',
#    'organizationName': 'Mayo',
#    'organizationId': 6,
#    'license': 'Creative Commons Zero 1.0 Universal',
#    'tags': ['canine', 'epilepsy', 'intracranial', 'continuous', 'eeg'],
#    'version': 1,
#    'revision': None,
#    'size': 263615741197,
#    'modelCount': [{'modelName': 'Channel', 'count': 48},
#     {'modelName': 'Recording', 'count': 3},
#     {'modelName': 'Subject', 'count': 3},
#     {'modelName': 'Annotation', 'count': 219}],
#    'fileCount': 61,
#    'recordCount': 273,
#    'uri': 's3://pennsieve-prod-discover-publish-use1/3/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/3/1/',
#    'status': 'PUBLISH_SUCCEEDED',
#    'doi': '10.26275/ju7v-hnyy',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/3/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/3/1/readme.md',
#    'contributors': [{'firstName': 'Andrew',
#      'middleInitial': None,
#      'lastName': 'B. Gardner',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Ankit',
#      'middleInitial': None,
#      'lastName': 'N. Khambhati',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Benjamin',
#      'middleInitial': None,
#      'lastName': 'H. Brinkmann',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Beverly',
#      'middleInitial': None,
#      'lastName': 'K. Sturges',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Brian',
#      'middleInitial': None,
#      'lastName': 'Litt',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Charles',
#      'middleInitial': None,
#      'lastName': 'H. Vite',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Drausin',
#      'middleInitial': None,
#      'lastName': 'Wulsin',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Emily',
#      'middleInitial': None,
#      'lastName': 'Fox',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Erin',
#      'middleInitial': None,
#      'lastName': 'C. Conrad',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Gregory',
#      'middleInitial': None,
#      'lastName': 'Worrell',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Hoameng',
#      'middleInitial': None,
#      'lastName': 'Ung',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'John',
#      'middleInitial': None,
#      'lastName': 'J. McDonnell',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Joost',
#      'middleInitial': None,
#      'lastName': 'Wagenaar',
#      'degree': None,
#      'orcid': '0000-0003-0837-7120'},
#     {'firstName': 'Kathryn',
#      'middleInitial': None,
#      'lastName': 'A. Davis',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Kent',
#      'middleInitial': None,
#      'lastName': 'Leyde',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Mark',
#      'middleInitial': None,
#      'lastName': 'J. Cook',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Ned',
#      'middleInitial': None,
#      'lastName': 'Patterson',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Steven',
#      'middleInitial': None,
#      'lastName': 'N. Baldassano',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Tyler',
#      'middleInitial': None,
#      'lastName': 'Blevins',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Vanessa',
#      'middleInitial': None,
#      'lastName': 'Ruedebusch',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'W.',
#      'middleInitial': None,
#      'lastName': 'Douglas Sheffield',
#      'degree': None,
#      'orcid': None}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '1.0',
#    'createdAt': '2019-07-03T18:14:25.256Z',
#    'updatedAt': '2019-10-17T16:28:17.866977Z',
#    'firstPublishedAt': '2019-07-03T18:14:25.212Z',
#    'versionPublishedAt': '2019-07-03T18:14:25.256Z',
#    'revisedAt': None,
#    'embargo': False,
#    'embargoReleaseDate': None,
#    'embargoAccess': None},
#   {'id': 275,
#    'sourceDatasetId': 1969,
#    'name': 'Test Embargo dataset',
#    'description': 'This is a test dataset for SPARC to test request to embargo datasets',
#    'ownerId': 29,
#    'ownerFirstName': 'Joost',
#    'ownerLastName': 'Wagenaar',
#    'ownerOrcid': '0000-0003-0837-7120',
#    'organizationName': 'SPARC Consortium',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['test'],
#    'version': 1,
#    'revision': None,
#    'size': 4315620,
#    'modelCount': [],
#    'fileCount': 21,
#    'recordCount': 0,
#    'uri': 's3://pennsieve-prod-discover-embargo-use1/275/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-embargo-use1/275/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/xioi-rjik',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/275/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/275/1/readme.md',
#    'contributors': [{'firstName': 'Joost',
#      'middleInitial': 'B',
#      'lastName': 'Wagenaar',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0003-0837-7120'}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-08-21T16:34:08.092297Z',
#    'updatedAt': '2022-08-21T16:40:52.661054Z',
#    'firstPublishedAt': '2022-08-21T16:34:08.084103Z',
#    'versionPublishedAt': '2022-08-21T16:34:08.092297Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-01-01',
#    'embargoAccess': None},
#   {'id': 214,
#    'sourceDatasetId': 72,
#    'name': 'Test Dataset CNT',
#    'description': 'This is another test dataset for timeseries data',
#    'ownerId': 29,
#    'ownerFirstName': 'Joost',
#    'ownerLastName': 'Wagenaar',
#    'ownerOrcid': '0000-0003-0837-7120',
#    'organizationName': 'Penn CNT',
#    'organizationId': 20,
#    'license': 'Apache 2.0',
#    'tags': ['test'],
#    'version': 1,
#    'revision': None,
#    'size': 3241745,
#    'modelCount': [],
#    'fileCount': 6,
#    'recordCount': 0,
#    'uri': 's3://pennsieve-prod-discover-publish-use1/214/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/214/1/',
#    'status': 'PUBLISH_SUCCEEDED',
#    'doi': '10.26275/lksl-tazl',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/214/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/214/1/readme.md',
#    'contributors': [{'firstName': 'Joost',
#      'middleInitial': 'B',
#      'lastName': 'Wagenaar',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0003-0837-7120'}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-02-13T19:02:18.992868Z',
#    'updatedAt': '2022-02-13T19:07:54.42547Z',
#    'firstPublishedAt': '2022-02-13T19:02:18.987456Z',
#    'versionPublishedAt': '2022-02-13T19:02:18.992868Z',
#    'revisedAt': None,
#    'embargo': False,
#    'embargoReleaseDate': None,
#    'embargoAccess': None},
#   {'id': 87,
#    'sourceDatasetId': 14,
#    'name': 'Scientific Articles',
#    'description': 'A collection of relevant articles around Bioelectronic medicine, Biomarkers and digital health care',
#    'ownerId': 29,
#    'ownerFirstName': 'Joost',
#    'ownerLastName': 'Wagenaar',
#    'ownerOrcid': '0000-0003-0837-7120',
#    'organizationName': 'Blackfynn',
#    'organizationId': 24,
#    'license': 'Creative Commons Attribution - ShareAlike',
#    'tags': ['articles', 'books'],
#    'version': 1,
#    'revision': None,
#    'size': 34590482,
#    'modelCount': [],
#    'fileCount': 36,
#    'recordCount': 0,
#    'uri': 's3://pennsieve-prod-discover-publish-use1/87/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/87/1/',
#    'status': 'PUBLISH_SUCCEEDED',
#    'doi': '10.26275/k64z-n56w',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/87/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/87/1/readme.md',
#    'contributors': [{'firstName': 'Joost',
#      'middleInitial': 'B',
#      'lastName': 'Wagenaar',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0003-0837-7120'},
#     {'firstName': 'Leonardo',
#      'middleInitial': 'A',
#      'lastName': 'Guercio',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-9471-878X'}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2020-09-25T00:57:48.335203Z',
#    'updatedAt': '2021-09-24T00:01:36.973895Z',
#    'firstPublishedAt': '2020-09-25T00:31:18.1117Z',
#    'versionPublishedAt': '2020-09-25T00:57:48.335203Z',
#    'revisedAt': None,
#    'embargo': False,
#    'embargoReleaseDate': '2021-09-24',
#    'embargoAccess': None},
#   {'id': 2,
#    'sourceDatasetId': 6912,
#    'name': 'Hetionet',
#    'description': 'An integrative disease network. Hetionet is an integrative network of biomedical knowledge assembled from 29 different databases of genes, compounds, diseases, and more.',
#    'ownerId': 29,
#    'ownerFirstName': 'Joost',
#    'ownerLastName': 'Wagenaar',
#    'ownerOrcid': '0000-0003-0837-7120',
#    'organizationName': 'Blackfynn',
#    'organizationId': 24,
#    'license': 'Creative Commons Zero 1.0 Universal',
#    'tags': ['hetionet', 'hetnet', 'drug-interaction', 'integrative-data'],
#    'version': 2,
#    'revision': 1,
#    'size': 3515096005,
#    'modelCount': [{'modelName': 'Anatomy', 'count': 402},
#     {'modelName': 'Cellular_Component', 'count': 1391},
#     {'modelName': 'Molecular_Function', 'count': 2884},
#     {'modelName': 'Compound', 'count': 1552},
#     {'modelName': 'Gene', 'count': 20945},
#     {'modelName': 'Pathway', 'count': 1822},
#     {'modelName': 'Side_Effect', 'count': 5734},
#     {'modelName': 'Symptom', 'count': 438},
#     {'modelName': 'Disease', 'count': 137},
#     {'modelName': 'Pharmacologic_Class', 'count': 345},
#     {'modelName': 'Biological_Process', 'count': 11381}],
#    'fileCount': 47,
#    'recordCount': 47031,
#    'uri': 's3://pennsieve-prod-discover-publish-use1/2/2/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/2/2/',
#    'status': 'PUBLISH_SUCCEEDED',
#    'doi': '10.26275/t6j6-77pu',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/2/2/revisions/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/2/2/revisions/1/readme.md',
#    'contributors': [{'firstName': 'Daniel',
#      'middleInitial': None,
#      'lastName': 'S Himmelstein',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Antoine',
#      'middleInitial': None,
#      'lastName': 'Lizee',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Christine',
#      'middleInitial': None,
#      'lastName': 'Hessler',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Leo',
#      'middleInitial': None,
#      'lastName': 'Brueggeman',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Sabrina',
#      'middleInitial': None,
#      'lastName': 'L Chen',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Dexter',
#      'middleInitial': None,
#      'lastName': 'Hadley',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Ari',
#      'middleInitial': None,
#      'lastName': 'Green',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Pouya',
#      'middleInitial': None,
#      'lastName': 'Khankhanian',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Sergio',
#      'middleInitial': None,
#      'lastName': 'E Baranzini',
#      'degree': None,
#      'orcid': None}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2020-03-12T15:37:35.69799Z',
#    'updatedAt': '2020-11-30T19:28:38.789446Z',
#    'firstPublishedAt': '2019-07-01T16:56:52.157Z',
#    'versionPublishedAt': '2020-03-12T15:37:35.69799Z',
#    'revisedAt': '2020-07-23T20:49:21.883489Z',
#    'embargo': False,
#    'embargoReleaseDate': None,
#    'embargoAccess': None}]}

# %% [markdown]
# We can query the Discover service with different options, e.g. looking within certain organization, only for embargoed datasets, and order the records by name, date, size in ascending or descending direction.

# %%
response=client.pennsieve.list_datasets(organization='Sparc', embargo=True, order_by='date', order_direction='asc')
response
# Out:
# {'limit': 10,
#  'offset': 0,
#  'totalCount': 5,
#  'datasets': [{'id': 238,
#    'sourceDatasetId': 1560,
#    'name': 'Mapping colon and bladder innervating sensory neurons in CLARITY cleared ganglia in mouse',
#    'description': 'Imaging of colon and bladder retrograde labelled sensory neurons in whole CLARITY cleared dorsal root ganglia and nodose/jugular ganglia complex.',
#    'ownerId': 1205,
#    'ownerFirstName': 'Stuart',
#    'ownerLastName': 'Brierley',
#    'ownerOrcid': '0000-0002-2527-2905',
#    'organizationName': 'SPARC Consortium',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['visceral sensory neurons', 'dorsal root ganglia'],
#    'version': 1,
#    'revision': None,
#    'size': 52139108574,
#    'modelCount': [{'modelName': 'researcher', 'count': 2},
#     {'modelName': 'human_subject', 'count': 0},
#     {'modelName': 'term', 'count': 2},
#     {'modelName': 'award', 'count': 0},
#     {'modelName': 'animal_subject', 'count': 21},
#     {'modelName': 'sample', 'count': 21},
#     {'modelName': 'protocol', 'count': 2},
#     {'modelName': 'summary', 'count': 4}],
#    'fileCount': 1519,
#    'recordCount': 52,
#    'uri': 's3://pennsieve-prod-discover-embargo-use1/238/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-embargo-use1/238/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/be0x-9mzy',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/238/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/238/1/readme.md',
#    'contributors': [{'firstName': 'Stuart',
#      'middleInitial': 'M',
#      'lastName': 'Brierley',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-2527-2905'},
#     {'firstName': 'Andrea',
#      'middleInitial': None,
#      'lastName': 'Harrington',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-1562-4137'}],
#    'collections': [],
#    'externalPublications': [{'doi': '10.17504/protocols.io.x54v9y391g3e/v1',
#      'relationshipType': 'IsSupplementedBy'},
#     {'doi': '10.17504/protocols.io.j8nlkk971l5r/v2',
#      'relationshipType': 'IsSupplementedBy'},
#     {'doi': '10.17504/protocols.io.14egn7mpqv5d/v1',
#      'relationshipType': 'IsSupplementedBy'}],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-05-16T22:55:44.441079Z',
#    'updatedAt': '2022-05-16T23:26:19.975536Z',
#    'firstPublishedAt': '2022-05-16T22:52:25.571113Z',
#    'versionPublishedAt': '2022-05-16T22:55:44.441079Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-04-13',
#    'embargoAccess': None},
#   {'id': 240,
#    'sourceDatasetId': 1566,
#    'name': 'Imaging colon and bladder sensory convergence in CLARITY cleared mouse spinal cord ',
#    'description': 'Colon and bladder innervating sensory nerves were identified by retrograde tracing and imaged in the whole CLARITY cleared spinal cord to identify the distribution of colon/bladder dichotomizing input.',
#    'ownerId': 1205,
#    'ownerFirstName': 'Stuart',
#    'ownerLastName': 'Brierley',
#    'ownerOrcid': '0000-0002-2527-2905',
#    'organizationName': 'SPARC Consortium',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['spinal cord', 'visceral sensory neurons'],
#    'version': 1,
#    'revision': None,
#    'size': 35086316992,
#    'modelCount': [{'modelName': 'researcher', 'count': 2},
#     {'modelName': 'human_subject', 'count': 0},
#     {'modelName': 'term', 'count': 2},
#     {'modelName': 'award', 'count': 0},
#     {'modelName': 'animal_subject', 'count': 4},
#     {'modelName': 'sample', 'count': 4},
#     {'modelName': 'protocol', 'count': 2},
#     {'modelName': 'summary', 'count': 4}],
#    'fileCount': 960,
#    'recordCount': 18,
#    'uri': 's3://pennsieve-prod-discover-embargo-use1/240/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-embargo-use1/240/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/iyto-oxay',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/240/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/240/1/readme.md',
#    'contributors': [{'firstName': 'Stuart',
#      'middleInitial': 'M',
#      'lastName': 'Brierley',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-2527-2905'},
#     {'firstName': 'Andrea',
#      'middleInitial': None,
#      'lastName': 'Harrington',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-1562-4137'}],
#    'collections': [{'id': 203,
#      'name': 'Colon/Blader sensory neurons ganglia in mouse'}],
#    'externalPublications': [{'doi': '10.17504/protocols.io.14egn7mpqv5d/v1',
#      'relationshipType': 'IsSupplementedBy'},
#     {'doi': '10.17504/protocols.io.j8nlkk971l5r/v1',
#      'relationshipType': 'IsSupplementedBy'},
#     {'doi': '10.17504/protocols.io.x54v9y391g3e/v1',
#      'relationshipType': 'IsSupplementedBy'},
#     {'doi': '10.17504/protocols.io.j8nlkk971l5r/v2',
#      'relationshipType': 'IsSupplementedBy'}],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-05-16T22:58:25.293618Z',
#    'updatedAt': '2022-05-16T23:19:02.803414Z',
#    'firstPublishedAt': '2022-05-16T22:58:25.287602Z',
#    'versionPublishedAt': '2022-05-16T22:58:25.293618Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-04-13',
#    'embargoAccess': None},
#   {'id': 258,
#    'sourceDatasetId': 835,
#    'name': '4D upper gastrointestinal magnetic resonance imaging in healthy human subjects and gastroparetic patients',
#    'description': 'This aims to characterize gastric motility and emptying patterns in healthy human subjects and gastroparetic patients by using 4D contrast-enhanced MRI.',
#    'ownerId': 362,
#    'ownerFirstName': 'Deborah',
#    'ownerLastName': 'Jaffey',
#    'ownerOrcid': '0000-0003-4738-4024',
#    'organizationName': 'SPARC Consortium',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['gastroparesis', 'gastric mri', 'human', 'motility'],
#    'version': 1,
#    'revision': None,
#    'size': 667525924872,
#    'modelCount': [{'modelName': 'researcher', 'count': 12},
#     {'modelName': 'human_subject', 'count': 0},
#     {'modelName': 'term', 'count': 0},
#     {'modelName': 'award', 'count': 1},
#     {'modelName': 'animal_subject', 'count': 47},
#     {'modelName': 'sample', 'count': 0},
#     {'modelName': 'protocol', 'count': 1},
#     {'modelName': 'summary', 'count': 6}],
#    'fileCount': 1999,
#    'recordCount': 67,
#    'uri': 's3://pennsieve-prod-discover-embargo-use1/258/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-embargo-use1/258/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/23je-ute3',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/258/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/258/1/readme.md',
#    'contributors': [{'firstName': 'Kun-Han',
#      'middleInitial': None,
#      'lastName': 'Lu',
#      'degree': None,
#      'orcid': '0000-0002-0355-8515'},
#     {'firstName': 'Kristine',
#      'middleInitial': None,
#      'lastName': 'Mosier',
#      'degree': None,
#      'orcid': '0000-0002-4595-4647'},
#     {'firstName': 'Zhongming',
#      'middleInitial': None,
#      'lastName': 'Liu',
#      'degree': None,
#      'orcid': '0000-0002-8773-4204'},
#     {'firstName': 'John',
#      'middleInitial': None,
#      'lastName': 'Wo',
#      'degree': None,
#      'orcid': '0000-0002-3142-3255'},
#     {'firstName': 'Anita',
#      'middleInitial': None,
#      'lastName': 'Gupta',
#      'degree': None,
#      'orcid': '0000-0001-8032-9081'},
#     {'firstName': 'Megan',
#      'middleInitial': None,
#      'lastName': 'Jarrett',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Travis',
#      'middleInitial': None,
#      'lastName': 'Putzke',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Deborah',
#      'middleInitial': None,
#      'lastName': 'Jaffey',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0003-4738-4024'},
#     {'firstName': 'Jiayue',
#      'middleInitial': None,
#      'lastName': 'Cao',
#      'degree': None,
#      'orcid': '0000-0002-9040-1929'},
#     {'firstName': 'Xiaokai',
#      'middleInitial': None,
#      'lastName': 'Wang',
#      'degree': None,
#      'orcid': None},
#     {'firstName': 'Bartek',
#      'middleInitial': None,
#      'lastName': 'Rajwa',
#      'degree': None,
#      'orcid': '0000-0001-7540-8236'},
#     {'firstName': 'Terry',
#      'middleInitial': 'L',
#      'lastName': 'Powley',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0001-6689-7058'}],
#    'collections': [],
#    'externalPublications': [{'doi': '10.17504/protocols.io.kxygxpx9dl8j/v1',
#      'relationshipType': 'IsSupplementedBy'}],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-07-13T16:58:31.363476Z',
#    'updatedAt': '2022-07-13T17:45:48.880189Z',
#    'firstPublishedAt': '2022-07-13T16:58:31.321955Z',
#    'versionPublishedAt': '2022-07-13T16:58:31.363476Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-02-15',
#    'embargoAccess': None},
#   {'id': 275,
#    'sourceDatasetId': 1969,
#    'name': 'Test Embargo dataset',
#    'description': 'This is a test dataset for SPARC to test request to embargo datasets',
#    'ownerId': 29,
#    'ownerFirstName': 'Joost',
#    'ownerLastName': 'Wagenaar',
#    'ownerOrcid': '0000-0003-0837-7120',
#    'organizationName': 'SPARC Consortium',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['test'],
#    'version': 1,
#    'revision': None,
#    'size': 4315620,
#    'modelCount': [],
#    'fileCount': 21,
#    'recordCount': 0,
#    'uri': 's3://pennsieve-prod-discover-embargo-use1/275/1/',
#    'arn': 'arn:aws:s3:::pennsieve-prod-discover-embargo-use1/275/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/xioi-rjik',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/275/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/275/1/readme.md',
#    'contributors': [{'firstName': 'Joost',
#      'middleInitial': 'B',
#      'lastName': 'Wagenaar',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0003-0837-7120'}],
#    'collections': [],
#    'externalPublications': [],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2022-08-21T16:34:08.092297Z',
#    'updatedAt': '2022-08-21T16:40:52.661054Z',
#    'firstPublishedAt': '2022-08-21T16:34:08.084103Z',
#    'versionPublishedAt': '2022-08-21T16:34:08.092297Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-01-01',
#    'embargoAccess': None},
#   {'id': 293,
#    'sourceDatasetId': 2113,
#    'name': 'Mouse genetic models to manipulate enterochromaffin cell activity',
#    'description': 'Immunohistochemical validation of mouse genetic strategies used to specifically activate and silence enterochromaffin cells in the intestine',
#    'ownerId': 1336,
#    'ownerFirstName': 'Nathan',
#    'ownerLastName': 'Rossen',
#    'ownerOrcid': '0000-0002-1103-0833',
#    'organizationName': 'SPARC',
#    'organizationId': 367,
#    'license': 'Creative Commons Attribution',
#    'tags': ['serotonin',
#     'intestine',
#     'immunohistochemistry',
#     'colon',
#     'mouse',
#     'visceral pain',
#     'enterochromaffin cell'],
#    'version': 1,
#    'revision': None,
#    'size': 93662312044,
#    'modelCount': [{'modelName': 'researcher', 'count': 4},
#     {'modelName': 'human_subject', 'count': 0},
#     {'modelName': 'animal_subject', 'count': 3},
#     {'modelName': 'sample', 'count': 15},
#     {'modelName': 'term', 'count': 1},
#     {'modelName': 'award', 'count': 1},
#     {'modelName': 'protocol', 'count': 1},
#     {'modelName': 'summary', 'count': 3}],
#    'fileCount': 72,
#    'recordCount': 28,
#    'uri': 's3://prd-sparc-embargo-use1/293/1/',
#    'arn': 'arn:aws:s3:::prd-sparc-embargo-use1/293/1/',
#    'status': 'EMBARGO_SUCCEEDED',
#    'doi': '10.26275/f4p0-d1ic',
#    'banner': 'https://assets.discover.pennsieve.io/dataset-assets/293/1/banner.jpg',
#    'readme': 'https://assets.discover.pennsieve.io/dataset-assets/293/1/readme.md',
#    'contributors': [{'firstName': 'Nathan',
#      'middleInitial': 'D',
#      'lastName': 'Rossen',
#      'degree': None,
#      'orcid': '0000-0002-1103-0833'},
#     {'firstName': 'David',
#      'middleInitial': None,
#      'lastName': 'Julius',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-2527-2905'},
#     {'firstName': 'Stuart',
#      'middleInitial': 'M',
#      'lastName': 'Brierley',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0002-2527-2905'},
#     {'firstName': 'Holly',
#      'middleInitial': None,
#      'lastName': 'Ingraham',
#      'degree': 'Ph.D.',
#      'orcid': '0000-0001-6739-2967'}],
#    'collections': [{'id': 319,
#      'name': 'Mouse genetic models to manipulate enterochromaffin cell activity'}],
#    'externalPublications': [{'doi': '10.1101/2022.04.04.486775',
#      'relationshipType': 'IsDescribedBy'},
#     {'doi': '10.17504/protocols.io.j8nlkw575l5r/v1',
#      'relationshipType': 'IsSupplementedBy'}],
#    'sponsorship': None,
#    'pennsieveSchemaVersion': '4.0',
#    'createdAt': '2023-01-06T22:21:15.666489Z',
#    'updatedAt': '2023-01-06T22:30:33.280743Z',
#    'firstPublishedAt': '2023-01-06T19:35:12.690948Z',
#    'versionPublishedAt': '2023-01-06T22:21:15.666489Z',
#    'revisedAt': None,
#    'embargo': True,
#    'embargoReleaseDate': '2023-10-06',
#    'embargoAccess': None}]}

# %% [markdown]
# #### Listing records

# %% [markdown]
# Apart from listing the dataset, we can also zoom into the records of a given dataset for a specific model, for example explore researchers within Sparc project.

# %%
response=client.pennsieve.list_records(model='researcher', organization='Sparc')
response
# Out:
# {'limit': 10,
#  'offset': 0,
#  'totalCount': 1141,
#  'records': [{'datasetId': 282,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0002-0067-510X',
#     'hasAffiliation': 'Univeristy of California, Los Angeles;University of California, Los Angeles;https://ror.org/046rm7j60',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Yuan',
#     'recordHash': '82329d634a673e2f45a1bfe90930e5fc',
#     'firstName': 'Pu-Qing',
#     'id': '3136648b-e83d-4e30-a20c-d6af747712d5'}},
#   {'datasetId': 287,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0002-4153-9614',
#     'hasAffiliation': 'University College London',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Thompson',
#     'recordHash': '77fbf8f43a9adb0180b8d1c8d289e6f6',
#     'firstName': 'Nicole',
#     'id': 'ea50a52a-54a3-4180-ace6-0b6b59beeb2a'}},
#   {'datasetId': 301,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': '',
#     'hasAffiliation': 'Micro-Leads Inc., Somerville, MA, United States of America',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Ogren',
#     'recordHash': '4334a0f127d16f027b5439388b0dc430',
#     'firstName': 'John',
#     'id': 'b0836808-c334-4d5f-8534-8996392e5e28'}},
#   {'datasetId': 290,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': '',
#     'hasAffiliation': 'Flinders University;Flinders University:\xa0Adelaide,\xa0SA,\xa0AU',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Humenick',
#     'recordHash': 'd266bf7ea9c5602297fbd8afe7aa1dfe',
#     'firstName': 'Adam',
#     'id': 'cb46c218-5111-4db6-a0b4-292d86ff887e'}},
#   {'datasetId': 290,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0001-7803-3556',
#     'hasAffiliation': 'University of Veterinary Medicine Hannover',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Mazzuoli-Weber',
#     'recordHash': 'b4029aae0174b6d1feb0fe99c979a747',
#     'firstName': 'Gemma',
#     'id': '2d0a07cf-44e4-45f7-a6b1-c4a7b36122e6'}},
#   {'datasetId': 295,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': '',
#     'hasAffiliation': 'Department of Psychological Sciences, Purdue University, West Lafayette, Indiana, United States;https://ror.org/02dqehb95',
#     'middleName': 'L',
#     'hasRole': '',
#     'lastName': 'Chesney',
#     'recordHash': '1f3b237f9130b87b4d18b1a40631a404',
#     'firstName': 'Logan',
#     'id': '58eed0be-07f1-4aca-bbcb-49f596d64a81'}},
#   {'datasetId': 295,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0002-5963-8733',
#     'hasAffiliation': 'Department of Psychological Sciences, Purdue University, West Lafayette, Indiana, United States;[1] Department of Psychological Sciences, Purdue University, West Lafayette, IN, USA;[1] Department of Psychological Sciences, Purdue University, West Lafayette, Indiana, United States\n[2] Purdue Institute for Integrative Neuroscience, Purdue University, West Lafayette, IN, USA;https://ror.org/02dqehb95',
#     'middleName': 'J',
#     'hasRole': '',
#     'lastName': 'Phillips',
#     'recordHash': 'd569c5de1bff414ab5e063f899c9112a',
#     'firstName': 'Robert',
#     'id': 'd157e246-f0d3-4683-804c-0e1af0b98079'}},
#   {'datasetId': 294,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': '',
#     'hasAffiliation': 'Department of Anatomy & Neuroscience, University of Melbourne, Parkville, VIC;https://ror.org/01ej9dk98',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Pustovit',
#     'recordHash': '41c82f32b7451a5b67a3f793157494bf',
#     'firstName': 'Ruslan',
#     'id': '7fdbb373-6794-436f-bca2-40433c83606c'}},
#   {'datasetId': 292,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0002-6388-2181',
#     'hasAffiliation': 'Auckland Bioegineering Institute;Auckland Bioengineering Institute',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Lin',
#     'recordHash': '075a928fd502fe552055020acb088f7d',
#     'firstName': 'Mabelle',
#     'id': '9e9991f9-233a-4487-b01d-cf5640ac1f9f'}},
#   {'datasetId': 304,
#    'version': 1,
#    'model': 'researcher',
#    'properties': {'hasORCIDId': 'https://orcid.org/0000-0002-0757-546X',
#     'hasAffiliation': 'George Washington University',
#     'middleName': '',
#     'hasRole': '',
#     'lastName': 'Brennan',
#     'recordHash': '89761686f401b2845b59009d81f57a9b',
#     'firstName': 'Jaclyn',
#     'id': '4491ddda-9820-4af8-a288-793c85ce8d34'}}]}

# %% [markdown]
# #### Listing files

# %% [markdown]
# Similarly, we can query for files that are related with given name, or extension, e.g. that are included in a specific dataset.

# %%
response=client.pennsieve.list_files(dataset_id=90, query='manifest', file_type='json')
response
# Out:
# [{'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 19928,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None},
#  {'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 1660,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/revisions/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None}]

# %% [markdown]
# If we are only interested in relative paths of the files, for convenienve we can use list_filenames() function.

# %%
response=client.pennsieve.list_filenames(dataset_id=90, query='manifest')
response
# Out:
# ['files/primary/sub-898/manifest.xlsx',
#  'manifest.json',
#  'files/primary/sub-897/manifest.xlsx',
#  'files/primary/sub-896/manifest.xlsx',
#  'revisions/1/manifest.json',
#  'files/derivative/manifest.xlsx']

# %% [markdown]
# #### Downloading files

# %% [markdown]
# Downloading files is also very simple. All we need to do is to list file(s) that are to be downloaded and pass it to the download_files function.
#
# The function will either download the file with its original extension (if output_name is not specified) or pack the files and download them in gzip format to the specified directory.

# %%
# !dir
# Out:
# Beginners\ guide.ipynb

# %%
response=client.pennsieve.list_file(dataset_id=90, query='manifest', file_type='json')
client.pennsieve.download_files(file_list=response, output_name='myfile')
# !dir
# Out:
# Beginners\ guide.ipynb	myfile.gz

# %%
response=client.pennsieve.list_file(dataset_id=90, query='manifest', file_type='json')
client.pennsieve.download_file(file_list=response[0])
# !dir
# Out:
# Beginners\ guide.ipynb	download  myfile.gz

# %%
# !gunzip

# %%
response[0].get('namesdf') is None
# Out:
# True

# %%
response=client.pennsieve.list_files(dataset_id=90, query='manifest')
response
# Out:
# [{'name': 'manifest.xlsx',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 10502,
#   'fileType': 'MSExcel',
#   'packageType': 'Unsupported',
#   'icon': 'Excel',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-898/manifest.xlsx',
#   'createdAt': None,
#   'sourcePackageId': 'N:package:825b9c5c-efe7-42ef-8421-22a23d319217'},
#  {'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 19928,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None},
#  {'name': 'manifest.xlsx',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 10647,
#   'fileType': 'MSExcel',
#   'packageType': 'Unsupported',
#   'icon': 'Excel',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-897/manifest.xlsx',
#   'createdAt': None,
#   'sourcePackageId': 'N:package:99029aaa-e8e6-44c6-bb45-33a9b17a4e92'},
#  {'name': 'manifest.xlsx',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 10581,
#   'fileType': 'MSExcel',
#   'packageType': 'Unsupported',
#   'icon': 'Excel',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-896/manifest.xlsx',
#   'createdAt': None,
#   'sourcePackageId': 'N:package:f806424d-4022-4d98-8c38-236e94709807'},
#  {'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 1660,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/revisions/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None},
#  {'name': 'manifest.xlsx',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 12297,
#   'fileType': 'MSExcel',
#   'packageType': 'Unsupported',
#   'icon': 'Excel',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/derivative/manifest.xlsx',
#   'createdAt': None,
#   'sourcePackageId': 'N:package:036562a9-85b1-4247-8c56-1a104f0d335e'}]

# %%
#paths = ['files/derivative/manifest.xlsx']
paths = ['files/derivative/manifest.xlsx']

json = {
        "data": {
            "paths": paths,
            "datasetId": 90,
            "version": 1,
        }
    }

headers = {"content-type": "application/json"}


response=client.pennsieve.post('https://api.pennsieve.io/zipit/discover/', json=json, headers=headers)
response.content
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [68], line 15
#       4 json = {
#       5         "data": {
#       6             "paths": paths,
#    (...)
#       9         }
#      10     }
#      12 headers = {"content-type": "application/json"}
# ---> 15 response=client.pennsieve.post('https://api.pennsieve.io/zipit/discover/', json=json, headers=headers)
#      16 response.content
#
# File ~/.local/lib/python3.10/site-packages/sparc/client/services/pennsieve.py:368, in PennsieveService.post(self, url, json, **kwargs)
#     351 def post(self, url, json, **kwargs):
#     352     """Invokes POST endpoint on a server. Passing server name in url is optional.
#     353
#     354     Parameters:
#    (...)
#     366     String in JSON format with response from the server.
#     367     """
# --> 368     return self.Pennsieve.post(url, json=json, **kwargs)
#
# File ~/IdeaProjects/pennsieve-agent-python/src/pennsieve2/pennsieve.py:332, in Pennsieve.post(self, url, json, **kwargs)
#     315 def post(self, url, json, **kwargs):
#     316     """Invokes POST endpoint on a server. Passing server name in url is optional.
#     317
#     318     Parameters:
#    (...)
#     330     String in JSON format with response from the server.
#     331     """
# --> 332     return self.call(url, method="post", json=json, **kwargs)
#
# File ~/IdeaProjects/pennsieve-agent-python/src/pennsieve2/pennsieve.py:290, in Pennsieve.call(self, url, method, **kwargs)
#     287 except:  # pylint: disable=W0702
#     288     traceback.print_exc()
# --> 290 return response.json()
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !pennsieve agent
# Out:
# Pennsieve Agent started on port: 9000

# %%
paths = [x if x.get("name") is None else x.get("name") for x in response]
response
# Out:
# [{'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 19928,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None},
#  {'name': 'manifest.json',
#   'datasetId': 90,
#   'datasetVersion': 1,
#   'size': 1660,
#   'fileType': 'Json',
#   'packageType': 'Unsupported',
#   'icon': 'JSON',
#   'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/revisions/1/manifest.json',
#   'createdAt': None,
#   'sourcePackageId': None}]

# %%
client.pennsieve.download_files(['files/derivative/manifest.xlsx'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 client.pennsieve.download_files(['files/primary/sub-897/manifest.xlsx'])
#
# File ~/.local/lib/python3.10/site-packages/sparc/client/services/pennsieve.py:299, in PennsieveService.download_files(self, file_list, output_name)
#     296 file_list = [file_list] if type(file_list) is dict else file_list
#     298 # create a tuple with datasetId and version of the dataset
# --> 299 properties = set([(x["datasetId"], x["datasetVersion"]) for x in file_list])
#     301 # extract all the files
#     302 paths = [x["name"] for x in file_list]
#
# File ~/.local/lib/python3.10/site-packages/sparc/client/services/pennsieve.py:299, in <listcomp>(.0)
#     296 file_list = [file_list] if type(file_list) is dict else file_list
#     298 # create a tuple with datasetId and version of the dataset
# --> 299 properties = set([(x["datasetId"], x["datasetVersion"]) for x in file_list])
#     301 # extract all the files
#     302 paths = [x["name"] for x in file_list]
#
# TypeError: string indices must be integers

# %%
import os
def download_files(json, output_name):
    url = "https://api.pennsieve.io/zipit/discover"
    json = [json] if type(json) is dict else json
    print(json)
    properties=set([(x['datasetId'], x['datasetVersion']) for x in json])
    print(properties)
    paths = [x['name'] for x in json]
    print(len(paths))
    assert len(properties) == 1, "Downloading files from multiple datasets or dataset versions is not supported."
    data = {"data": {
        "paths":  paths,
        "datasetId": next(iter(properties))[0],
        "version": next(iter(properties))[1]
    }}

    # download the files with zipit service
    headers = {"content-type": "application/json"}
    response = requests.post(url, json=data, headers=headers)
    extension = output_name.split('.')[-1]
    output_name = output_name if len(paths)==1 else os.path.splitext(output_name)[0]+'.gz'
    with open(output_name, mode='wb+') as f:
        f.write(response.content)

# %%
download_files(response['files'],'aa')
# Out:
# [{'name': 'manifest.json', 'datasetId': 90, 'datasetVersion': 1, 'size': 19928, 'fileType': 'Json', 'packageType': 'Unsupported', 'icon': 'JSON', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/manifest.json', 'createdAt': None, 'sourcePackageId': None}, {'name': 'manifest.json', 'datasetId': 90, 'datasetVersion': 1, 'size': 1660, 'fileType': 'Json', 'packageType': 'Unsupported', 'icon': 'JSON', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/revisions/1/manifest.json', 'createdAt': None, 'sourcePackageId': None}, {'name': 'manifest.xlsx', 'datasetId': 90, 'datasetVersion': 1, 'size': 10502, 'fileType': 'MSExcel', 'packageType': 'Unsupported', 'icon': 'Excel', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-898/manifest.xlsx', 'createdAt': None, 'sourcePackageId': 'N:package:825b9c5c-efe7-42ef-8421-22a23d319217'}, {'name': 'manifest.xlsx', 'datasetId': 90, 'datasetVersion': 1, 'size': 10647, 'fileType': 'MSExcel', 'packageType': 'Unsupported', 'icon': 'Excel', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-897/manifest.xlsx', 'createdAt': None, 'sourcePackageId': 'N:package:99029aaa-e8e6-44c6-bb45-33a9b17a4e92'}, {'name': 'manifest.xlsx', 'datasetId': 90, 'datasetVersion': 1, 'size': 10581, 'fileType': 'MSExcel', 'packageType': 'Unsupported', 'icon': 'Excel', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-896/manifest.xlsx', 'createdAt': None, 'sourcePackageId': 'N:package:f806424d-4022-4d98-8c38-236e94709807'}, {'name': 'manifest.xlsx', 'datasetId': 90, 'datasetVersion': 1, 'size': 12297, 'fileType': 'MSExcel', 'packageType': 'Unsupported', 'icon': 'Excel', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/derivative/manifest.xlsx', 'createdAt': None, 'sourcePackageId': 'N:package:036562a9-85b1-4247-8c56-1a104f0d335e'}, {'name': 'schema.json', 'datasetId': 90, 'datasetVersion': 1, 'size': 23537, 'fileType': 'Json', 'packageType': 'Unsupported', 'icon': 'JSON', 'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/schema.json', 'createdAt': None, 'sourcePackageId': None}]
# {(90, 1)}
# 7

# %%
uri='s3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-898/manifest.xlsx'
'/'.join(uri.split('/')[5:])
# Out:
# 'files/primary/sub-898/manifest.xlsx'

# %%
import requests
    
url = "https://api.pennsieve.io/zipit/discover"

data = {"data": {
        "paths":  ["files/subjects.xlsx","files/dataset_description.xlsx"],
        "version": 1,
        "datasetId": 295
    }}


data = {"data": {
        "paths": ["metadata/schema.json"],
        "version": 1,
        "datasetId": 90
    }}





headers = {"content-type": "application/json"}
                
response = requests.post(url, json=data, headers=headers)

print(response.text)
# Out:
# {
#     "models": [
#         {
#             "name": "summary",
#             "displayName": "Summary",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "title",
#                     "displayName": "Title",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "isDescribedBy",
#                     "displayName": "Publication URL",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "description",
#                     "displayName": "Description",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "collectionTitle",
#                     "displayName": "Collection Title",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "milestoneCompletionDate",
#                     "displayName": "Milestone Completion Date",
#                     "description": "",
#                     "dataType": {
#                         "type": "Date"
#                     }
#                 },
#                 {
#                     "name": "curationIndex",
#                     "displayName": "Curation index",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasExperimentalModality",
#                     "displayName": "Experimental modality",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfContributors",
#                     "displayName": "Number of contributors",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfDirectories",
#                     "displayName": "Number of directories",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfFiles",
#                     "displayName": "Number of files",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfSamples",
#                     "displayName": "Number of samples",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfSubjects",
#                     "displayName": "Number of subjects",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "acknowledgements",
#                     "displayName": "Acknowledgements",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "submissionIndex",
#                     "displayName": "Submission index",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "errorIndex",
#                     "displayName": "Error index",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "label",
#                     "displayName": "Label",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasSizeInBytes",
#                     "displayName": "Size (bytes)",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasAwardNumber",
#                     "displayName": "Award number",
#                     "description": "",
#                     "dataType": {
#                         "to": "award",
#                         "file": "records/summary.csv",
#                         "type": "Model"
#                     }
#                 }
#             ],
#             "file": "records/summary.csv"
#         },
#         {
#             "name": "animal_subject",
#             "displayName": "Animal Subject",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "localId",
#                     "displayName": "Subject ID",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "animalSubjectIsOfStrain",
#                     "displayName": "Animal strain",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "animalSubjectHasWeight",
#                     "displayName": "Animal weight",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasAge",
#                     "displayName": "Age",
#                     "description": "",
#                     "dataType": {
#                         "type": "Double",
#                         "unit": "day"
#                     }
#                 },
#                 {
#                     "name": "protocolExecutionDate",
#                     "displayName": "Protocol execution date",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "Date"
#                         }
#                     }
#                 },
#                 {
#                     "name": "localExecutionNumber",
#                     "displayName": "Execution number",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasAssignedGroup",
#                     "displayName": "Group",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "spatialLocationOfModulator",
#                     "displayName": "Spatial location of modulator",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "stimulatorUtilized",
#                     "displayName": "Stimulator utilized",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "providerNote",
#                     "displayName": "Provider note",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasGenotype",
#                     "displayName": "Genotype",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "involvesAnatomicalRegion",
#                     "displayName": "Anatomical region involved",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "wasAdministeredAnesthesia",
#                     "displayName": "Anesthesia administered",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "specimenHasIdentifier",
#                     "displayName": "Identifier",
#                     "description": "",
#                     "dataType": {
#                         "to": "term",
#                         "file": "records/animal_subject.csv",
#                         "type": "Model"
#                     }
#                 },
#                 {
#                     "name": "hasBiologicalSex",
#                     "displayName": "Biological sex",
#                     "description": "",
#                     "dataType": {
#                         "to": "term",
#                         "file": "records/animal_subject.csv",
#                         "type": "Model"
#                     }
#                 },
#                 {
#                     "name": "hasAgeCategory",
#                     "displayName": "Age category",
#                     "description": "",
#                     "dataType": {
#                         "to": "term",
#                         "file": "records/animal_subject.csv",
#                         "type": "Model"
#                     }
#                 },
#                 {
#                     "name": "animalSubjectIsOfSpecies",
#                     "displayName": "Animal species",
#                     "description": "",
#                     "dataType": {
#                         "to": "term",
#                         "file": "records/animal_subject.csv",
#                         "type": "Model"
#                     }
#                 }
#             ],
#             "file": "records/animal_subject.csv"
#         },
#         {
#             "name": "researcher",
#             "displayName": "Researcher",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "lastName",
#                     "displayName": "Last name",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "firstName",
#                     "displayName": "First name",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "middleName",
#                     "displayName": "Middle name",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasAffiliation",
#                     "displayName": "Affiliation",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasRole",
#                     "displayName": "Role",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasORCIDId",
#                     "displayName": "ORCID iD",
#                     "description": "",
#                     "dataType": {
#                         "type": "String",
#                         "format": "URL"
#                     }
#                 }
#             ],
#             "file": "records/researcher.csv"
#         },
#         {
#             "name": "protocol",
#             "displayName": "Protocol",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "label",
#                     "displayName": "Name",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "url",
#                     "displayName": "URL",
#                     "description": "",
#                     "dataType": {
#                         "type": "String",
#                         "format": "URL"
#                     }
#                 },
#                 {
#                     "name": "publisher",
#                     "displayName": "publisher",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "date",
#                     "displayName": "Date",
#                     "description": "",
#                     "dataType": {
#                         "type": "Date"
#                     }
#                 },
#                 {
#                     "name": "protocolHasNumberOfSteps",
#                     "displayName": "Number of Steps",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasNumberOfProtcurAnnotations",
#                     "displayName": "Number of Protcur Annotations",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 }
#             ],
#             "file": "records/protocol.csv"
#         },
#         {
#             "name": "award",
#             "displayName": "Award",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "award_id",
#                     "displayName": "Award ID",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "title",
#                     "displayName": "Title",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "description",
#                     "displayName": "Description",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "principal_investigator",
#                     "displayName": "Principal Investigator",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 }
#             ],
#             "file": "records/award.csv"
#         },
#         {
#             "name": "sample",
#             "displayName": "Sample",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "label",
#                     "displayName": "Label",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "id",
#                     "displayName": "id",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "description",
#                     "displayName": "Description",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "hasAssignedGroup",
#                     "displayName": "Group",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "extractedFrom",
#                     "displayName": "Extract Location",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hasDigitalArtifactThatIsAboutIt",
#                     "displayName": "Digital artifact",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "localExecutionNumber",
#                     "displayName": "Execution number",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "providerNote",
#                     "displayName": "Provider note",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "wasDerivedFromSubject",
#                     "displayName": "Derived from subject",
#                     "description": "",
#                     "dataType": {
#                         "to": "animal_subject",
#                         "file": "records/sample.csv",
#                         "type": "Model"
#                     }
#                 }
#             ],
#             "file": "records/sample.csv"
#         },
#         {
#             "name": "term",
#             "displayName": "Term",
#             "description": "",
#             "properties": [
#                 {
#                     "name": "label",
#                     "displayName": "Label",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "curie",
#                     "displayName": "CURIE",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "definitions",
#                     "displayName": "Definition",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 },
#                 {
#                     "name": "abbreviations",
#                     "displayName": "Abbreviations",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "synonyms",
#                     "displayName": "Synonyms",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "acronyms",
#                     "displayName": "Acronyms",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "categories",
#                     "displayName": "Categories",
#                     "description": "",
#                     "dataType": {
#                         "type": "Array",
#                         "items": {
#                             "type": "String"
#                         }
#                     }
#                 },
#                 {
#                     "name": "iri",
#                     "displayName": "IRI",
#                     "description": "",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 }
#             ],
#             "file": "records/term.csv"
#         },
#         {
#             "name": "file",
#             "displayName": "File",
#             "description": "A file in the dataset",
#             "properties": [
#                 {
#                     "name": "path",
#                     "displayName": "Path",
#                     "description": "The path to the file from the root of the dataset",
#                     "dataType": {
#                         "type": "String"
#                     }
#                 }
#             ],
#             "file": "records/file.csv"
#         }
#     ],
#     "relationships": [
#         {
#             "name": "hasContactPerson",
#             "from": "summary",
#             "to": "researcher",
#             "file": "relationships/hasContactPerson.csv"
#         },
#         {
#             "name": "hasResponsiblePrincipalInvestigator",
#             "from": "summary",
#             "to": "researcher",
#             "file": "relationships/hasResponsiblePrincipalInvestigator.csv"
#         }
#     ]
# }

# %% [markdown]
# ## Download files

# %%
import requests
    
url = "https://api.pennsieve.io/zipit/discover"

data = {"data": {
        "paths":  ["files/subjects.xlsx","files/dataset_description.xlsx"],
        "version": 1,
        "datasetId": 295
    }}


data = {"data": {
        "paths": ["files/samples.xlsx"],
        "version": 1,
        "datasetId": 295
    }}





headers = {"content-type": "application/json"}
                
response = requests.post(url, json=data, headers=headers)

print(response.text)
# Out:
# #f%VAMb��docProps/app.xmlM�=1D��q��A�Bb@�R��{/�dC�B~�9��noF�
# #f%V�>�:�docProps/core.xmlŒOO1ſ
# #f%V���� xl/theme/theme1.xml�Y�o�6��� ��J�%u
# [���4A�v葖i�1%$��(
# s��ym��Ϯ�-� �-�0)'[�%|F�
# �N?��}�Z
# Q�#��릟��\`0.�r|�_
# |�M�|y�w6�ݮ��a4k�x�Uo�U��
# _��W�f۩*�P�7ж[){��.!CFoh�u��VKs�
# ee�k&ɼX�!�]��E�D��N����%}N�2
#  �&(b��ݵ���9i+�(��(#=���P��>'�0o�V3y�����秏?}�����7�n�h��{��7�����o?�~��/��W�|��?ߤ^*��{���������O5�&G�,�GB,�;�ظ�BX�f�����((�ؑ��3ET�kaՄ�9d
# �����7Z��Է񑊄m��N%����X�P��4��A2Б<�r_1��������:�=>U�ކ�w�.��*�K2�!wcYd����-gY�M1�E�>�ZL�!I���\w�'X�o[߃���I�u[3u?N�a��&����D�x������ƽ�:<�0=�[d�Xg�[H�դaeRR�hK��x�r��N��E!�y��Ր��)�M�{�+���d��I��I�~���J�B�S�w����;��s�@b?�mz�b}���t"�^$�N�X����v�k��	I���g��q?N���
f0\x9d\xfc9i+\xf5(\xda\xc2(#=\x1b\xf2\xc5\xc6P\xc2\xc7\x10>\'\x13\xd90o\x81V3\x03y\xf9\xe2\xc5\xe9\xe3\xe7\xa7\x8f\x7f?}\xf2\xe4\xf4\xf1\xaf\xf3\xb97\xe5n\xa0h\x94\x95{\xfd\xd37\xff\xfc\xf0\xa5\xf1\xf7o?\xbe~\xfa\xad\x1e/\xb2\xf8W\xbf|\xf5\xea\x8f?\xdf\xa4^*\xb4\xbe{\xf6\xea\xf9\xb3\x97\xdf\x7f\xfd\xd7\xcfO5\xf0&G\xfd,\xbcGB,\x8c;\xf8\xd8\xb8\xcbBX\xa0f\x02\xdc\xe7\xe7\x93\xe8\x05\x88(\x12(\x00\xa4\x06\xd8\x91\x81\x02\xbc3ET\x87ka\xd5\x84\xf79d\n\x1d\xf0z|\xa8p=\x08x,\x89\x06x;\x08\x15\xe0.c\xb4\xc5\xb8v9\xb7\x93\xb9\xb2\xcb\x89\xa3\x91~r\x1egqw\x11:\xd2\xcd\xed\xad9\xb8\x13O \xe4\x89N\xa5\x17`\x85\xe6>\x05o\xa3\x11\x8e\xb04\x92gl\x8c\xb1F\xec\x01!\x8a]w\x89\xcf\x99`Ci< F\x0b\x11\xadIz\xa4/\xf5B7H\x08~\x99\xea\x08\x82\xab\x15\xdb\xec\xde7Z\x8c\xea\xd4\xb7\xf1\x91\x8a\x84m\x81\xa8N%\xa6\x8a\x19\xaf\xa3X\xa2P\xcb\x18\x854\x8b\xdcA2\xd0\x91<\x98r_1\xb8\x90\xe0\xe9\x11\xa6\xcc\xe8\x0c\xb0\x10:\x99=>U\xe8\xde\x86\x0c\xa3w\xfb.\x9d\x86*\x92K2\xd6!w\x10cYd\x9b\x8d\xbd\x00\x85\x13-g\x12\x05Y\xecM1\x86\x10E\xc6>\x93Z\x12L\xdd!I\x1f\xfc\x80\xa2\\w\xdf\'X\x9eo[\xdf\x83\x0c\xa4\x0f\x90\xe4I\xccu[\x023u?N\xe9\x10a\x9d\xf ...

# %%
response=a.pennsieve.list_files(query="*.png", limit=5000)['files']

# %%
data=set([(x['datasetId'], x['datasetVersion']) for x in response])
len(data)
# Out:
# 51

# %%
[x['name'] for x in response]
z=set([x['datasetId'] for x in response])
z
# Out:
# {10,
#  11,
#  12,
#  27,
#  33,
#  44,
#  57,
#  86,
#  89,
#  109,
#  115,
#  116,
#  117,
#  119,
#  123,
#  134,
#  137,
#  142,
#  147,
#  150,
#  156,
#  167,
#  169,
#  177,
#  180,
#  182,
#  183,
#  184,
#  185,
#  188,
#  207,
#  210,
#  211,
#  221,
#  229,
#  230,
#  236,
#  239,
#  242,
#  243,
#  244,
#  245,
#  247,
#  254,
#  256,
#  270,
#  271,
#  272,
#  287,
#  288,
#  303}

# %%
response=response[0]

# %%
response
# Out:
# {'limit': 10,
#  'offset': 0,
#  'totalCount': 10000,
#  'files': [{'name': 'Rat_896_Control_2_Abd Vag Ant Gas_100X_1(1)_01_02_19 (1).tif',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 17740866,
#    'fileType': 'TIFF',
#    'packageType': 'Slide',
#    'icon': 'Microscope',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-896/sam-2/Rat_896_Control_2_Abd Vag Ant Gas_100X_1(1)_01_02_19 (1).tif',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:07975557-9ef9-40f4-8060-2bafe9bebe7d'},
#   {'name': 'animal_subject.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 702,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/records/animal_subject.csv',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'banner.jpg',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 192863,
#    'fileType': 'JPEG',
#    'packageType': 'Image',
#    'icon': 'Image',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/banner.jpg',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'hasContactPerson.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 206,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/relationships/hasContactPerson.csv',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'manifest.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 12297,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/derivative/manifest.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:036562a9-85b1-4247-8c56-1a104f0d335e'},
#   {'name': 'readme.md',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 1609,
#    'fileType': 'Markdown',
#    'packageType': 'Unsupported',
#    'icon': 'Code',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/readme.md',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'samples.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 36770,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/samples.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:5282eb37-38d8-482b-9831-22ccab3d45d3'},
#   {'name': 'schema.json',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 23537,
#    'fileType': 'Json',
#    'packageType': 'Unsupported',
#    'icon': 'JSON',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/schema.json',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'subjects.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 48577,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/subjects.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:f57cabfd-e32a-4ae6-8bb1-863237d49c51'},
#   {'name': 'summary.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 1954,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/records/summary.csv',
#    'createdAt': None,
#    'sourcePackageId': None}]}

# %%
json = response if type(response) is dict else response
json
# Out:
# {'limit': 10,
#  'offset': 0,
#  'totalCount': 10000,
#  'files': [{'name': 'Rat_896_Control_2_Abd Vag Ant Gas_100X_1(1)_01_02_19 (1).tif',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 17740866,
#    'fileType': 'TIFF',
#    'packageType': 'Slide',
#    'icon': 'Microscope',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/primary/sub-896/sam-2/Rat_896_Control_2_Abd Vag Ant Gas_100X_1(1)_01_02_19 (1).tif',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:07975557-9ef9-40f4-8060-2bafe9bebe7d'},
#   {'name': 'animal_subject.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 702,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/records/animal_subject.csv',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'banner.jpg',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 192863,
#    'fileType': 'JPEG',
#    'packageType': 'Image',
#    'icon': 'Image',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/banner.jpg',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'hasContactPerson.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 206,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/relationships/hasContactPerson.csv',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'manifest.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 12297,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/derivative/manifest.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:036562a9-85b1-4247-8c56-1a104f0d335e'},
#   {'name': 'readme.md',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 1609,
#    'fileType': 'Markdown',
#    'packageType': 'Unsupported',
#    'icon': 'Code',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/readme.md',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'samples.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 36770,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/samples.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:5282eb37-38d8-482b-9831-22ccab3d45d3'},
#   {'name': 'schema.json',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 23537,
#    'fileType': 'Json',
#    'packageType': 'Unsupported',
#    'icon': 'JSON',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/schema.json',
#    'createdAt': None,
#    'sourcePackageId': None},
#   {'name': 'subjects.xlsx',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 48577,
#    'fileType': 'MSExcel',
#    'packageType': 'Unsupported',
#    'icon': 'Excel',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/files/subjects.xlsx',
#    'createdAt': None,
#    'sourcePackageId': 'N:package:f57cabfd-e32a-4ae6-8bb1-863237d49c51'},
#   {'name': 'summary.csv',
#    'datasetId': 90,
#    'datasetVersion': 1,
#    'size': 1954,
#    'fileType': 'CSV',
#    'packageType': 'CSV',
#    'icon': 'Tabular',
#    'uri': 's3://pennsieve-prod-discover-publish-use1/90/1/metadata/records/summary.csv',
#    'createdAt': None,
#    'sourcePackageId': None}]}

# %%
client.list_records()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [202], line 1
# ----> 1 client.list_records()
#
# AttributeError: 'SparcClient' object has no attribute 'list_records'

# %%
[x['name'] for x in response]
list(map(lambda x: '/'.join(x['uri'].split('/')[5:]), response))
# Out:
# ['files/primary/sub-PR1729/PR1729_258/2019-07-30_131.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_133.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_136.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_141.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_142.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_145.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_148.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_154.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_155.jpeg',
#  'files/primary/sub-PR1729/PR1729_258/2019-07-30_160.jpeg',
jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B84/B84_B/HB_84B_3/2018-01-16_131.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B84/B84_B/HB_84B_4/2018-01-16_134.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B84/B84_B/HB_84B_2/2018-01-16_143.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_1/2018-01-17_005.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_1/2018-01-17_007.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_3/2018-01-17_017.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_4/2018-01-17_024.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_4/2018-01-17_030.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/2018-01-17_031.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_4/2018-01-17_033.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_A/HB_80A_3/2018-01-17_033.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_B/HB_80B_1/2018-01-17_036.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_B/HB_80B_1/2018-01-17_041.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_B/HB_80B_4/2018-01-17_061.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_B/HB_80B_4/2018-01-17_062.jpeg',
#  'files/primary/sub-HB/Supplementary Sample Acquisition Images/B80/B80_B/2018-01-17_065.jpeg',
#  'files/primary/sub-PR1534/PR1534_190/2019-02-04_170.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_183.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_190.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_191.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_199.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_205.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_212.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_219.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_220.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_234.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_236.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_238.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_240.jpeg',
#  'files/primary/sub-PR1534/PR1534_40/2019-02-04_253.jpeg']

# %%
response['files']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 response['files']
#
# TypeError: 'Response' object is not subscriptable

# %%
files=['files/primary/sub-10163/sam-10163/10163_P_20_1_9.xml',
 'files/primary/sub-10176/sam-10176/10176_P_10_1_11.xml',
 'files/primary/sub-10207/sam-10207/10207_P_17_1_9.xml',
 'files/primary/sub-10246/sam-10246/10246_P_13_1_6.xml',
 'files/primary/sub-10284/sam-10284/10284_P_1_1_3.xml',
 'files/primary/sub-10444/sam-10444/10444_P_9_3_13.xml']

# %%
import requests
    
url = "https://api.pennsieve.io/zipit/discover"

data = {"data": {
        "paths": files,
        "version": 1,
        "datasetId": 295
    }}
headers = {"content-type": "application/json"}
                
response = requests.post(url, json=data, headers=headers)

#print(response.text)

# %% [markdown]
# ## Upload files to Pennsieve

# %%
In order to upload files to Pennsieve, a user needs to 

https://docs.pennsieve.io/docs/uploading-files-programmatically

# %%
# !pennsieve agent

# %%
client.

# %%
        local_filename = url.split('/')[-1]
        with requests.get(url, stream=True) as r:
            with open(local_filename, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
